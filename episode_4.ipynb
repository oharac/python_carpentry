# %%
import pandas as pd

surveys_df = pd.read_csv('data/surveys.csv')

x = [1, 2, 3, 4, 5]
x[1]
x[1:3]
x[1:1]
# Out:
# []

# %%
surveys_df.head()
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
surveys_df.species_id
survey_species = surveys_df['species_id']

# %%
surveys_df[['plot_id', 'species_id']]
# Out:
#        plot_id species_id
# 0            2         NL
# 1            3         NL
# 2            2         DM
# 3            7         DM
# 4            3         DM
# ...        ...        ...
# 35544       15         AH
# 35545       15         AH
# 35546       10         RM
# 35547        7         DO
# 35548        5        NaN
#
# [35549 rows x 2 columns]

# %%
survey_species[3] = 'test'
surveys_df.head()
# Out:
# C:\Users\casey\AppData\Local\Temp\ipykernel_32988\4210350267.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   survey_species[3] = 'test'
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7       test   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
true_copy_surveys_df = surveys_df.copy()

ref_surveys_df = surveys_df
ref_surveys_df[0:3] = 0

# %%
true_copy_surveys_df.head()

surveys_df = pd.read_csv('data/surveys.csv')
surveys_df.head()
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
surveys_df.iloc[0:7, 1:7]
# Out:
#    month  day  year  plot_id species_id sex
# 0      7   16  1977        2         NL   M
# 1      7   16  1977        3         NL   M
# 2      7   16  1977        2         DM   F
# 3      7   16  1977        7       test   M
# 4      7   16  1977        3         DM   M
# 5      7   16  1977        1         PF   M
# 6      7   16  1977        2         PE   F

# %%
surveys_df.iloc[0:4]
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7       test   M             36.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN

# %%
surveys_df[(surveys_df.year == 1999) & (surveys_df.weight <= 8)]
# Out:
#        record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 29082      29083      1   16  1999       21         RM   M             16.0
# 29196      29197      2   20  1999       18         RM   M             18.0
# 29421      29422      3   15  1999       16         RM   M             15.0
# 29903      29904     10   10  1999        4         PP   M             20.0
# 29905      29906     10   10  1999        4         PP   M             21.0
#
#        weight
# 29082     8.0
# 29196     8.0
# 29421     8.0
# 29903     7.0
# 29905     4.0

# %%
surveys_df[~surveys_df.species_id.isin(['NL', 'test'])]
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 2              3      7   16  1977        2         DM    F             37.0
# 4              5      7   16  1977        3         DM    M             35.0
# 5              6      7   16  1977        1         PF    M             14.0
# 6              7      7   16  1977        2         PE    F              NaN
# 7              8      7   16  1977        1         DM    M             37.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 2         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# ...       ...
# 35544     NaN
# 35545     NaN
# 35546    14.0
# 35547    51.0
# 35548     NaN
#
# [34296 rows x 9 columns]

# %%
new_df = surveys_df[pd.isnull(surveys_df.sex)]
new_df2 = surveys_df[~surveys_df.sex.isin(['M', 'F'])]
new_df.head()
# Out:
#     record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 13         14      7   16  1977        8         DM  NaN              NaN
# 18         19      7   16  1977        4         PF  NaN              NaN
# 33         34      7   17  1977       17         DM  NaN              NaN
# 56         57      7   18  1977       22         DM  NaN              NaN
# 76         77      8   19  1977        4         SS  NaN              NaN
#
#     weight
# 13     NaN
# 18     NaN
# 33     NaN
# 56     NaN
# 76     NaN

# %%
# selection of the data with isin
stack_selection = surveys_df[(surveys_df['sex'].isin(['M', 'F'])) &
              surveys_df["weight"] > 0.][["sex", "weight", "plot_id"]]
# calculate the mean weight for each plot id and sex combination:
stack_selection = stack_selection.groupby(["plot_id", "sex"]).mean().unstack()
# and we can make a stacked bar plot from this:
stack_selection.plot(kind='bar', stacked=True)
# Out:
# <Axes: xlabel='plot_id'>
